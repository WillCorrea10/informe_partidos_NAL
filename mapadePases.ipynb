# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import to_rgba
from urllib.request import urlopen
from mplsoccer import Pitch, FontManager, VerticalPitch, add_image
from PIL import Image
from statsbombpy import sb

# %%
fig ,ax = plt.subplots()
pitch = VerticalPitch()

pitch.draw(ax=ax)

# %%
fig ,ax = plt.subplots(figsize=(16,9))
pitch = VerticalPitch(pitch_type='opta')

pitch.draw(ax=ax)

pitch.scatter(50,70,ax=ax,s=50)
pitch.scatter(40,80,ax=ax,s=50)

pitch.arrows(50,70,40,80,ax=ax)

# %%
sb.matches(competition_id=223,season_id=282).sort_values('match_date')
# Out:
#     match_id  match_date      kick_off                   competition season  \
# 31   3939969  2024-06-21  03:00:00.000  South America - Copa America   2024
# 30   3939970  2024-06-22  03:00:00.000  South America - Copa America   2024
# 29   3939971  2024-06-23  04:00:00.000  South America - Copa America   2024
# 28   3939972  2024-06-23  01:00:00.000  South America - Copa America   2024
# 27   3939974  2024-06-24  01:00:00.000  South America - Copa America   2024
# 7    3939973  2024-06-24  04:00:00.000  South America - Copa America   2024
# 26   3939975  2024-06-25  01:00:00.000  South America - Copa America   2024
# 25   3939976  2024-06-25  04:00:00.000  South America - Copa America   2024
# 23   3939978  2024-06-26  01:00:00.000  South America - Copa America   2024
# 24   3939977  2024-06-26  04:00:00.000  South America - Copa America   2024
# 22   3939979  2024-06-27  04:00:00.000  South America - Copa America   2024
# ...

# %%
partido = sb.events(match_id=3943077)

# %%
partido.columns
# Out:
# Index(['50_50', 'bad_behaviour_card', 'ball_receipt_outcome',
#        'ball_recovery_offensive', 'ball_recovery_recovery_failure',
#        'block_deflection', 'block_offensive', 'carry_end_location',
#        'clearance_aerial_won', 'clearance_body_part', 'clearance_head',
#        'clearance_left_foot', 'clearance_right_foot', 'counterpress',
#        'dribble_nutmeg', 'dribble_outcome', 'dribble_overrun', 'duel_outcome',
#        'duel_type', 'duration', 'foul_committed_advantage',
#        'foul_committed_card', 'foul_committed_type', 'foul_won_advantage',
#        'foul_won_defensive', 'goalkeeper_body_part', 'goalkeeper_end_location',
#        'goalkeeper_outcome', 'goalkeeper_position', 'goalkeeper_technique',
#        'goalkeeper_type', 'id', 'index', 'injury_stoppage_in_chain',
#        'interception_outcome', 'location', 'match_id', 'minute', 'off_camera',
#        'out', 'pass_aerial_won', 'pass_angle', 'pass_assisted_shot_id',
# ...

# %%
partido.head()
# Out:
#   50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0   NaN                NaN                  NaN                     NaN
# 1   NaN                NaN                  NaN                     NaN
# 2   NaN                NaN                  NaN                     NaN
# 3   NaN                NaN                  NaN                     NaN
# 4   NaN                NaN                  NaN                     NaN
#
#   ball_recovery_recovery_failure block_deflection block_offensive  \
# 0                            NaN              NaN             NaN
# 1                            NaN              NaN             NaN
# 2                            NaN              NaN             NaN
# 3                            NaN              NaN             NaN
# 4                            NaN              NaN             NaN
#
#   carry_end_location clearance_aerial_won clearance_body_part  ...  \
# ...

# %%
partido.pass_outcome.value_counts()
# Out:
# pass_outcome
# Incomplete      178
# Out              22
# Unknown           7
# Pass Offside      2
# Name: count, dtype: int64

# %%
partido[['x', 'y']] = partido['location'].apply(pd.Series)
partido[['x_end', 'y_end']] = partido['pass_end_location'].apply(pd.Series)

# %%
partido['pasador']= partido['player']
partido['receptor']= partido['player'].shift(-1)
partido[['pasador','receptor']]
# Out:
#                               pasador                         receptor
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                                 NaN                              NaN
# ...                               ...                              ...
# 4103        Jhon Adolfo Arias Andrade     Luis Fernando Díaz Marulanda
# 4104     Luis Fernando Díaz Marulanda     Jefferson Andrés Lerma Solís
# 4105     Jefferson Andrés Lerma Solís  Ángel Fabián Di María Hernández
# 4106  Ángel Fabián Di María Hernández     Miguel Ángel Borja Hernández
# 4107     Miguel Ángel Borja Hernández                             None
#
# [4108 rows x 2 columns]

# %%
pases_partido=partido[(partido['type']=='Pass') & (partido['team']=='Colombia')]
pases_partido.shape
# Out:
# (659, 100)

# %%
pases_partido.pass_outcome.value_counts()
pases_partido[pases_partido['pass_outcome'].isna()==True]
# Out:
#      50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 22     NaN                NaN                  NaN                     NaN
# 23     NaN                NaN                  NaN                     NaN
# 24     NaN                NaN                  NaN                     NaN
# 25     NaN                NaN                  NaN                     NaN
# 36     NaN                NaN                  NaN                     NaN
# ...    ...                ...                  ...                     ...
# 1195   NaN                NaN                  NaN                     NaN
# 1198   NaN                NaN                  NaN                     NaN
# 1200   NaN                NaN                  NaN                     NaN
# 1201   NaN                NaN                  NaN                     NaN
# 1203   NaN                NaN                  NaN                     NaN
#
# ...

# %%
completados = pases_partido[pases_partido['pass_outcome'].isna()==True]

# %%
completados[['player','location','pass_end_location']]
# Out:
#                                player       location pass_end_location
# 22             Santiago Arias Naranjo   [41.9, 80.0]      [23.2, 64.8]
# 23              Davinson Sánchez Mina   [22.8, 60.5]       [6.3, 39.7]
# 24           Camilo Andrés Vargas Gil    [4.0, 36.3]      [14.8, 18.3]
# 25    Carlos Eccehomo Cuesta Figueroa   [17.4, 17.6]       [19.1, 5.7]
# 36           Camilo Andrés Vargas Gil    [6.0, 40.3]       [5.7, 53.0]
# ...                               ...            ...               ...
# 1195  Juan Fernando Quintero Paniagua    [86.7, 3.4]     [106.6, 32.7]
# 1198        Andrés Mateus Uribe Villa   [45.8, 21.5]      [55.7, 22.1]
# 1200           Santiago Arias Naranjo   [38.0, 62.7]      [59.1, 61.0]
# 1201    Jorge Andrés Carrascal Guardo   [64.0, 60.6]     [110.3, 26.8]
# 1203     Miguel Ángel Borja Hernández  [110.3, 27.5]     [112.3, 34.4]
#
# [554 rows x 3 columns]

# %%
completados[['player','x','y','x_end','y_end']]
# Out:
#                                player      x     y  x_end  y_end
# 22             Santiago Arias Naranjo   41.9  80.0   23.2   64.8
# 23              Davinson Sánchez Mina   22.8  60.5    6.3   39.7
# 24           Camilo Andrés Vargas Gil    4.0  36.3   14.8   18.3
# 25    Carlos Eccehomo Cuesta Figueroa   17.4  17.6   19.1    5.7
# 36           Camilo Andrés Vargas Gil    6.0  40.3    5.7   53.0
# ...                               ...    ...   ...    ...    ...
# 1195  Juan Fernando Quintero Paniagua   86.7   3.4  106.6   32.7
# 1198        Andrés Mateus Uribe Villa   45.8  21.5   55.7   22.1
# 1200           Santiago Arias Naranjo   38.0  62.7   59.1   61.0
# 1201    Jorge Andrés Carrascal Guardo   64.0  60.6  110.3   26.8
# 1203     Miguel Ángel Borja Hernández  110.3  27.5  112.3   34.4
#
# [554 rows x 5 columns]

# %%
completados['x'] = pd.to_numeric(completados['x'], errors='coerce')
completados['y'] = pd.to_numeric(completados['y'], errors='coerce')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7816\3658201310.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   completados['x'] = pd.to_numeric(completados['x'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_7816\3658201310.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   completados['y'] = pd.to_numeric(completados['y'], errors='coerce')

# %%
completados.groupby('player')[['x','y']].mean()
# Out:
#                                          x          y
# player
# Andrés Mateus Uribe Villa        46.744444  39.255556
# Camilo Andrés Vargas Gil         11.391667  40.080556
# Carlos Eccehomo Cuesta Figueroa  36.607692  27.882692
# Davinson Sánchez Mina            44.125714  58.711429
# James David Rodríguez Rubio      70.717308  35.990385
# Jefferson Andrés Lerma Solís     60.079310  33.127586
# Jhon Adolfo Arias Andrade        61.969388  20.926531
# Jhon Andrés Córdoba Copete       81.750000  41.620000
# Johan Andrés Mojica Palacio      61.132143   7.751786
# Jorge Andrés Carrascal Guardo    64.630769  24.669231
# Juan Fernando Quintero Paniagua  68.500000  42.304545
# Kevin Duvan Castaño Gil          58.694118  50.388235
# Luis Fernando Díaz Marulanda     79.341667  22.312500
# Miguel Ángel Borja Hernández     85.150000  33.750000
# Rafael Santos Borré Amaury       80.100000  32.320000
# Richard Rios Montoya             65.612821  52.307692
# ...

# %%
completados[['pasador','receptor']]
# Out:
#                               pasador                         receptor
# 22             Santiago Arias Naranjo            Davinson Sánchez Mina
# 23              Davinson Sánchez Mina         Camilo Andrés Vargas Gil
# 24           Camilo Andrés Vargas Gil  Carlos Eccehomo Cuesta Figueroa
# 25    Carlos Eccehomo Cuesta Figueroa      Johan Andrés Mojica Palacio
# 36           Camilo Andrés Vargas Gil            Davinson Sánchez Mina
# ...                               ...                              ...
# 1195  Juan Fernando Quintero Paniagua          Cristian Gabriel Romero
# 1198        Andrés Mateus Uribe Villa  Juan Fernando Quintero Paniagua
# 1200           Santiago Arias Naranjo    Jorge Andrés Carrascal Guardo
# 1201    Jorge Andrés Carrascal Guardo     Miguel Ángel Borja Hernández
# 1203     Miguel Ángel Borja Hernández            Davinson Sánchez Mina
#
# [554 rows x 2 columns]

# %%
firstSub = partido[(partido['type']=='Substitution') & (partido['team']=='Colombia')].minute.min()
firstSub
# Out:
# 87

# %%
completados = completados[completados['minute'] < firstSub]

# %%
average_locations = completados.groupby('player').agg({'x': ['mean'], 'y': ['mean', 'count']})
average_locations.columns = ['x', 'y', 'count']
average_locations
# Out:
#                                          x          y  count
# player
# Camilo Andrés Vargas Gil         11.792308  39.615385     26
# Carlos Eccehomo Cuesta Figueroa  36.194444  25.600000     36
# Davinson Sánchez Mina            44.207843  58.121569     51
# James David Rodríguez Rubio      72.050000  36.398000     50
# Jefferson Andrés Lerma Solís     60.212500  33.506250     48
# Jhon Adolfo Arias Andrade        62.992857  18.630952     42
# Jhon Andrés Córdoba Copete       81.750000  41.620000     10
# Johan Andrés Mojica Palacio      58.484444   7.566667     45
# Luis Fernando Díaz Marulanda     77.960000  18.255000     20
# Richard Rios Montoya             65.612821  52.307692     39
# Santiago Arias Naranjo           66.133333  69.570370     27

# %%
pass_between = completados.groupby(['pasador', 'receptor']).id.count().reset_index()
pass_between.rename({'id': 'pass_count'}, axis='columns',inplace=True)
pass_between
# Out:
#                              pasador                         receptor  \
# 0           Camilo Andrés Vargas Gil  Carlos Eccehomo Cuesta Figueroa
# 1           Camilo Andrés Vargas Gil            Davinson Sánchez Mina
# 2           Camilo Andrés Vargas Gil      Johan Andrés Mojica Palacio
# 3           Camilo Andrés Vargas Gil             Richard Rios Montoya
# 4    Carlos Eccehomo Cuesta Figueroa         Camilo Andrés Vargas Gil
# ..                               ...                              ...
# 96            Santiago Arias Naranjo      James David Rodríguez Rubio
# 97            Santiago Arias Naranjo     Jefferson Andrés Lerma Solís
# 98            Santiago Arias Naranjo        Jhon Adolfo Arias Andrade
# 99            Santiago Arias Naranjo       Jhon Andrés Córdoba Copete
# 100           Santiago Arias Naranjo             Richard Rios Montoya
#
#      pass_count
# 0             9
# 1            13
# 2             2
# 3             2
# 4             3
# ..          ...
# ...

# %%
pass_between = pass_between.merge(average_locations, left_on='pasador', right_index=True)
pass_between = pass_between.merge(average_locations, left_on='receptor', right_index=True, suffixes=['','_end'])
pass_between
# Out:
#                              pasador                         receptor  \
# 0           Camilo Andrés Vargas Gil  Carlos Eccehomo Cuesta Figueroa
# 1           Camilo Andrés Vargas Gil            Davinson Sánchez Mina
# 2           Camilo Andrés Vargas Gil      Johan Andrés Mojica Palacio
# 3           Camilo Andrés Vargas Gil             Richard Rios Montoya
# 4    Carlos Eccehomo Cuesta Figueroa         Camilo Andrés Vargas Gil
# ..                               ...                              ...
# 96            Santiago Arias Naranjo      James David Rodríguez Rubio
# 97            Santiago Arias Naranjo     Jefferson Andrés Lerma Solís
# 98            Santiago Arias Naranjo        Jhon Adolfo Arias Andrade
# 99            Santiago Arias Naranjo       Jhon Andrés Córdoba Copete
# 100           Santiago Arias Naranjo             Richard Rios Montoya
#
#      pass_count          x          y  count      x_end      y_end  count_end
# ...

# %%
pass_between = pass_between[pass_between['pass_count'] > 1]
pass_between
# Out:
#                              pasador                         receptor  \
# 0           Camilo Andrés Vargas Gil  Carlos Eccehomo Cuesta Figueroa
# 1           Camilo Andrés Vargas Gil            Davinson Sánchez Mina
# 2           Camilo Andrés Vargas Gil      Johan Andrés Mojica Palacio
# 3           Camilo Andrés Vargas Gil             Richard Rios Montoya
# 4    Carlos Eccehomo Cuesta Figueroa         Camilo Andrés Vargas Gil
# ..                               ...                              ...
# 95            Santiago Arias Naranjo            Davinson Sánchez Mina
# 96            Santiago Arias Naranjo      James David Rodríguez Rubio
# 97            Santiago Arias Naranjo     Jefferson Andrés Lerma Solís
# 99            Santiago Arias Naranjo       Jhon Andrés Córdoba Copete
# 100           Santiago Arias Naranjo             Richard Rios Montoya
#
#      pass_count          x          y  count      x_end      y_end  count_end
# ...

# %%
MAX_LINE_WIDTH = 13
pass_between['width'] = (pass_between.pass_count / pass_between.pass_count.max() * MAX_LINE_WIDTH)

MIN_TRANSPARENCY = 0.000001
color = np.array(to_rgba('yellow'))
color = np.tile(color, (len(pass_between), 1))
c_transparency = pass_between.pass_count / pass_between.pass_count.max()
c_transparency = (c_transparency * (1 - MIN_TRANSPARENCY)) + MIN_TRANSPARENCY
color[:, 3] = c_transparency

MAX_MARKER_SIZE=500
average_locations['marker_size'] = (average_locations['count'] / average_locations['count'].max() * MAX_MARKER_SIZE)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7816\3026530488.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pass_between['width'] = (pass_between.pass_count / pass_between.pass_count.max() * MAX_LINE_WIDTH)

# %%
pitch = VerticalPitch(pitch_type='statsbomb', pitch_color='#22312b', line_color='#c7d5cc', goal_type='box', goal_alpha=.8)
fig, ax = pitch.draw(figsize=(16, 11), constrained_layout=False, tight_layout=True)
fig.set_facecolor('#22312b')

# %%
pitch = VerticalPitch(pitch_type='statsbomb', pitch_color='#22312b', line_color='#c7d5cc', goal_type='box', goal_alpha=.8)
fig, ax = pitch.draw(figsize=(16, 11), constrained_layout=False, tight_layout=True)
fig.set_facecolor('#22312b')

arrows = pitch.arrows(pass_between.x, pass_between.y, pass_between.x_end, pass_between.y_end, ax=ax, color=color, zorder=.99)

nodes = pitch.scatter(average_locations.x, average_locations.y, ax=ax, color='white', ec='black', s=average_locations['marker_size'])

for index, row in pass_between[['pasador', 'x', 'y']].drop_duplicates(subset='pasador').iterrows():
    pitch.annotate(row.pasador.split(' ')[-2], xy=(row.x-4.5, row.y), c='white', va='center',
                       ha='center', size=14, weight='bold', ax=ax,zorder=1)

# %%
pitch = VerticalPitch(pitch_type='statsbomb', pitch_color='#22312b', line_color='#c7d5cc', goal_type='box', goal_alpha=.8)
fig, ax = pitch.draw(figsize=(9, 5), constrained_layout=False, tight_layout=True)
fig.set_facecolor('#22312b')

arrows = pitch.arrows(pass_between.x, pass_between.y, pass_between.x_end, pass_between.y_end, ax=ax, color=color, zorder=.99)

nodes = pitch.scatter(average_locations.x, average_locations.y, ax=ax, color='white', ec='black', s=average_locations['marker_size'])

for index, row in pass_between[['pasador', 'x', 'y']].drop_duplicates(subset='pasador').iterrows():
    pitch.annotate(row.pasador.split(' ')[-2], xy=(row.x-4.5, row.y), c='white', va='center',
                       ha='center', size=8, weight='bold', ax=ax,zorder=1)
